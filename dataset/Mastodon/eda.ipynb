# %%
import pandas as pd

# %%
df = pd.read_csv('mastodon_instance_info.csv')

# %%
df.describe()
# Out:
#         active_month   total_users   total_posts
# count     330.000000  3.290000e+02  3.290000e+02
# mean     1773.154545  1.747978e+04  1.046181e+06
# std     18077.599197  1.510128e+05  7.329157e+06
# min         3.000000  1.400000e+01  2.200000e+01
# 25%        58.250000  4.740000e+02  3.082800e+04
# 50%       169.500000  1.697000e+03  1.292600e+05
# 75%       603.500000  5.869000e+03  4.448710e+05
# max    327503.000000  2.711879e+06  1.297250e+08

# %%
df.notna().sum()
# Out:
# domain          330
# title           330
# source_url      330
# description     325
# active_month    330
# languages       330
# rules           330
# top_5_trends    330
# total_users     329
# total_posts     329
# blacklist       141
# dtype: int64

# %%
df_complete = df.dropna()
df_complete.to_csv('complete_data.csv', index=False)

# %%
df_complete.head(10)
# Out:
#                     domain                                    title  \
# 0          mastodon.social                                 Mastodon
# 1             mstdn.social                               Mastodon 🐘
# 2         infosec.exchange                         Infosec Exchange
# 3                   mas.to                                   mas.to
# 5               piaille.fr                                  Piaille
# 6             hachyderm.io                             Hachyderm.io
# 9               troet.cafe                   troet.cafe  - Mastodon
# 11  mastodon.gamedev.place                         Gamedev Mastodon
# 12          techhub.social                                  TechHub
# 13             mastodon.nl  Mastodon.nl door Stichting Activityclub
#
#                                 source_url  \
# 0     https://github.com/mastodon/mastodon
# 1     https://github.com/mastodon/mastodon
# 2   https://github.com/glitch-soc/mastodon
# 3     https://github.com/mastodon/mastodon
# 5     https://github.com/mastodon/mastodon
# 6     https://github.com/mastodon/mastodon
# 9     https://github.com/mastodon/mastodon
# 11    https://github.com/mastodon/mastodon
# 12    https://github.com/mastodon/mastodon
# 13    https://github.com/mastodon/mastodon
#
#                                           description  active_month languages  \
# 0   The original server operated by the Mastodon g...        327503    ["en"]
# 1   A general-purpose Mastodon server with a 500 c...         14546    ["en"]
# 2   A Mastodon instance for info/cyber security-mi...         13319    ["en"]
# 3   Hello! mas.to is a fast, up-to-date and fun Ma...         11889    ["en"]
# 5   Piaille.fr est un serveur mastodon public fran...          9221    ["fr"]
# 6   Hachyderm is a safe space, LGBTQIA+ and BLM, p...          8937    ["en"]
# 9   Hallo im troet.cafe!\r\nDies ist die derzeit g...          6850    ["de"]
# 11  Mastodon server focused on game development an...          5078    ["en"]
# 12  A hub primarily for passionate technologists, ...          5031    ["en"]
# 13  Mastodon voor de Nederlandse community - door ...          4519    ["en"]
#
#                                                 rules  \
# 0   [{"id": "1", "text": "Sexually explicit or vio...
# 1   [{"id": "2", "text": "Sexually explicit or vio...
# 2   [{"id": "1", "text": "Do unto others as you th...
# 3   [{"id": "9", "text": "No discrimination, inclu...
# 5   [{"id": "1", "text": "Conformément aux lois fr...
# 6   [{"id": "1", "text": "Don't be a dick.", "hint...
# 9   [{"id": "3", "text": "Keine Belästigung, Stalk...
# 11  [{"id": "1", "text": "Sexually explicit or vio...
# 12  [{"id": "6", "text": "Violent media must be ma...
# 13  [{"id": "2", "text": "Heb respect voor elkaar"...
#
#                                          top_5_trends  total_users  \
# 0   [{"day": "1746144000", "uses": "156", "account...    2711879.0
# 1   [{"day": "1746144000", "uses": "146", "account...     260323.0
# 2   [{"day": "1746144000", "uses": "141", "account...      75725.0
# 3   [{"day": "1746144000", "uses": "144", "account...     183608.0
# 5   [{"day": "1746144000", "uses": "39", "accounts...      40869.0
# 6   [{"day": "1746144000", "uses": "136", "account...      56318.0
# 9   [{"day": "1746144000", "uses": "101", "account...      46749.0
# 11  [{"day": "1746144000", "uses": "58", "accounts...      33441.0
# 12  [{"day": "1746144000", "uses": "137", "account...      83099.0
# 13  [{"day": "1746144000", "uses": "23", "accounts...      43744.0
#
#     total_posts                                          blacklist
# 0   129725014.0  ac.akirin.xyz | activitypub.awakari.com | bgza...
# 1    19904208.0  aet**.*om | ali**.*ar | a.sukazyo.cc | birdsit...
# 2     4296664.0  430022.xyz | adforward.org | amiga.team | ap.m...
# 3    10834206.0  alive.bar | decept.org | fediblock.lol | humbl...
# 5     3220626.0  ac.akirin.xyz | bar***.*et | beta.birdsite.liv...
# 6     4025216.0  asst****.***ial | cryp*****.lol | cunn******.t...
# 9     3852226.0  0x3c.pl | 430022.xyz | 9kb.me | academia.pub |...
# 11    1700682.0  admins.town | brands.town | ediot.social | fre...
# 12    2178838.0  abraham.su | airwaves.social | archaeology.soc...
# 13    2916058.0  9kb.me | bird.makeup | cryptodon.lol | mastodo...

# %%
df_complete.shape
# Out:
# (140, 11)
